# %%
#6. Write a python program which takes two inputs from user and print them addition

num1,num2 = int(input()),int(input())
print("Answer after addition: ",int(num1+num2))
# Out:
# 5
# 6
# Answer after addition:  11
