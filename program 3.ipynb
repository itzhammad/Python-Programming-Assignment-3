# %%
#Write a Python program to display the current date and time.
import datetime as dt
print(dt.datetime.now())
# Out:
# 2021-10-23 15:03:47.597385
