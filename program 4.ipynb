# %%
#4. Write a Python program which accepts the radius of a circle from the user and compute the area.

radius = float(input())
area_of_circle = 3.142 * (radius)*(radius)
print("Area of Circle is: %.2f"%area_of_circle)  # %.2f is used to round down the floating number to two digits after point (.)
# Out:
# 53
# Area of Circle is: 8825.88
